# %% [markdown]
# # **Different types of thresholding methods for SEM images**
#
# *   Image source: https://www.stinstruments.com/applications/energy/understanding-battery-materials-with-electron-microscopy/

# %%
#importing

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
from skimage.filters import threshold_sauvola, threshold_niblack
from skimage.morphology import skeletonize

# Upload SEM image
uploaded = files.upload()
file_name = next(iter(uploaded))
img = cv2.imread(file_name)

# Convert to grayscale
if len(img.shape) == 3:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
else:
    gray = img.copy()

print("Image shape:", gray.shape)

# Function image + histogram
def show_image_and_hist(image, threshold=None, title="Histogram"):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].imshow(image, cmap='gray')
    axes[0].set_title("SEM Image")
    axes[0].axis('off')
    axes[1].hist(image.ravel(), bins=256, range=(0, 255), color='gray')
    axes[1].set_title(title)
    axes[1].set_xlabel("Pixel Intensity")
    axes[1].set_ylabel("Frequency")
    if threshold is not None:
        axes[1].axvline(int(threshold), color='red', linestyle='--', linewidth=2)
    plt.show()

#Otsu Thresholding

otsu_val, otsu_img = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
print("Otsu Threshold:", otsu_val)
show_image_and_hist(gray, threshold=otsu_val, title="Histogram (Otsu)")
plt.figure(figsize=(6,6))
plt.imshow(otsu_img, cmap='gray')
plt.title("otsu Threshold")
plt.axis('off'); plt.show()
# Out:
#      <input type="file" id="files-457b70cb-e1e8-4177-9896-0267b94b8aa4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-457b70cb-e1e8-4177-9896-0267b94b8aa4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# SEM Image Processing Pipeline for Crack Analysis

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
from skimage.filters import threshold_sauvola, threshold_niblack
from skimage.morphology import skeletonize

# Upload SEM image

uploaded = files.upload()
file_name = next(iter(uploaded))
img = cv2.imread(file_name)

# grayscale

if len(img.shape) == 3:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
else:
    gray = img.copy()

print("Image shape:", gray.shape)

# Function image + histogram
def show_image_and_hist(image, threshold=None, title="Histogram"):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].imshow(image, cmap='gray')
    axes[0].set_title("SEM Image")
    axes[0].axis('off')
    axes[1].hist(image.ravel(), bins=256, range=(0, 255), color='gray')
    axes[1].set_title(title)
    axes[1].set_xlabel("Pixel Intensity")
    axes[1].set_ylabel("Frequency")
    if threshold is not None:
        axes[1].axvline(int(threshold), color='red', linestyle='--', linewidth=2)
    plt.show()

#Adaptive Mean Thresholding

mean_img = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C,
                                 cv2.THRESH_BINARY, 11, 2)
show_image_and_hist(gray, title="Histogram")
plt.figure(figsize=(6,6))
plt.imshow(mean_img, cmap='gray')
plt.title("Adaptive Mean Threshold")
plt.axis('off'); plt.show()
# Out:
#      <input type="file" id="files-60c54b06-4f97-478d-90b0-854b884c0917" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-60c54b06-4f97-478d-90b0-854b884c0917">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#imporing

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
from skimage.filters import threshold_sauvola, threshold_niblack
from skimage.morphology import skeletonize

#Upload SEM image
uploaded = files.upload()
file_name = next(iter(uploaded))
img = cv2.imread(file_name)

# Convert grayscale
if len(img.shape) == 3:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
else:
    gray = img.copy()

print("Image shape:", gray.shape)

# Function image + histogram
def show_image_and_hist(image, threshold=None, title="Histogram"):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].imshow(image, cmap='gray')
    axes[0].set_title("SEM Image")
    axes[0].axis('off')
    axes[1].hist(image.ravel(), bins=256, range=(0, 255), color='gray')
    axes[1].set_title(title)
    axes[1].set_xlabel("Pixel Intensity")
    axes[1].set_ylabel("Frequency")
    if threshold is not None:
        axes[1].axvline(int(threshold), color='red', linestyle='--', linewidth=2)
    plt.show()

#Adaptive Gaussian Thresholding
gauss_img = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                  cv2.THRESH_BINARY, 11, 2)
show_image_and_hist(gray, title="Histogram (Adaptive Gaussian)")
plt.figure(figsize=(6,6))
plt.imshow(mean_img, cmap='gray')
plt.title("Adaptive Gaussian Threshold")
plt.axis('off'); plt.show()
# Out:
#      <input type="file" id="files-7736f935-1db4-436c-af6f-dc1123a5a799" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7736f935-1db4-436c-af6f-dc1123a5a799">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#importing

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
from skimage.filters import threshold_sauvola, threshold_niblack
from skimage.morphology import skeletonize

#Upload SEM image
uploaded = files.upload()
file_name = next(iter(uploaded))
img = cv2.imread(file_name)

# Convert grayscale
if len(img.shape) == 3:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
else:
    gray = img.copy()

print("Image shape:", gray.shape)

# Function image + histogram
def show_image_and_hist(image, threshold=None, title="Histogram"):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].imshow(image, cmap='gray')
    axes[0].set_title("SEM Image")
    axes[0].axis('off')
    axes[1].hist(image.ravel(), bins=256, range=(0, 255), color='gray')
    axes[1].set_title(title)
    axes[1].set_xlabel("Pixel Intensity")
    axes[1].set_ylabel("Frequency")
    if threshold is not None:
        axes[1].axvline(int(threshold), color='red', linestyle='--', linewidth=2)
    plt.show()

sauvola_thresh = threshold_sauvola(gray)
sauvola_img = (gray > sauvola_thresh).astype(np.uint8) * 255
show_image_and_hist(gray, title="Histogram")
plt.figure(figsize=(4,4))
plt.imshow(sauvola_img, cmap='gray')
plt.title("Sauvola Threshold")
plt.axis('off'); plt.show()
# Out:
#      <input type="file" id="files-49230834-b33c-4eee-a7fd-b9c1f7c2cebd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49230834-b33c-4eee-a7fd-b9c1f7c2cebd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#imporitng

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
from skimage.filters import threshold_sauvola, threshold_niblack
from skimage.morphology import skeletonize


#Upload SEM image
uploaded = files.upload()
file_name = next(iter(uploaded))
img = cv2.imread(file_name)

# Convert grayscale
if len(img.shape) == 3:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
else:
    gray = img.copy()

print("Image shape:", gray.shape)

# Function image + histogram
def show_image_and_hist(image, threshold=None, title="Histogram"):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].imshow(image, cmap='gray')
    axes[0].set_title("SEM Image")
    axes[0].axis('off')
    axes[1].hist(image.ravel(), bins=256, range=(0, 255), color='gray')
    axes[1].set_title(title)
    axes[1].set_xlabel("Pixel Intensity")
    axes[1].set_ylabel("Frequency")
    if threshold is not None:
        axes[1].axvline(int(threshold), color='red', linestyle='--', linewidth=2)
    plt.show()

#Niblack Thresholding
niblack_thresh = threshold_niblack(gray, k=0.2)
niblack_img = (gray > niblack_thresh).astype(np.uint8) * 255
show_image_and_hist(gray, title="Histogram")
plt.figure(figsize=(4,4))
plt.imshow(sauvola_img, cmap='gray')
plt.title("Niblack Threshold")
plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-f28e103f-6c4a-4738-8b23-201ee27c5f0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f28e103f-6c4a-4738-8b23-201ee27c5f0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#importing

import cv2
import numpy as np
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow
from google.colab import files
from skimage.filters import threshold_sauvola, threshold_niblack
from skimage.morphology import skeletonize

#Upload SEM image
uploaded = files.upload()
file_name = next(iter(uploaded))
img = cv2.imread(file_name)

# Convert grayscale
if len(img.shape) == 3:
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
else:
    gray = img.copy()

print("Image shape:", gray.shape)

# Function image + histogram
def show_image_and_hist(image, threshold=None, title="Histogram"):
    fig, axes = plt.subplots(1, 2, figsize=(12, 4))
    axes[0].imshow(image, cmap='gray')
    axes[0].set_title("SEM Image")
    axes[0].axis('off')
    axes[1].hist(image.ravel(), bins=256, range=(0, 255), color='gray')
    axes[1].set_title(title)
    axes[1].set_xlabel("Pixel Intensity")
    axes[1].set_ylabel("Frequency")
    if threshold is not None:
        axes[1].axvline(int(threshold), color='red', linestyle='--', linewidth=2)
    plt.show()

# Canny Edge Detection

edges = cv2.Canny(gray, 50, 150)
show_image_and_hist(gray, title="Histogram")
plt.figure(figsize=(4,4))
plt.imshow(edges, cmap='gray')
plt.title("Canny Threshold")
plt.axis('off')
plt.show()
# Out:
#      <input type="file" id="files-98e6231f-2a41-46aa-aee0-b70bcec110cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-98e6231f-2a41-46aa-aee0-b70bcec110cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
