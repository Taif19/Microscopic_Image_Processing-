# %% [markdown]
# ## Denoising Image (Only Gaussian Filter)

# %% [markdown]
# image credit : "Noise2Void - Learning Denoising from Single Noisy Images
# Supplementary Note"
# Alexander Krull1,2
# , Tim-Oliver Buchholz2
# , Florian Jug

# %%
# !pip install scikit-image scipy matplotlib

from skimage import io, color, img_as_float, img_as_ubyte
from scipy import ndimage as nd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files

# Upload image
print("📤 Upload your noisy image:")
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# Read image
img = io.imread(img_path)

# If image has 4 channels (RGBA), convert to RGB
if img.ndim == 3 and img.shape[-1] == 4:
    img = img[..., :3]

# Convert to grayscale and normalize
gray = color.rgb2gray(img)
gray = img_as_float(gray)

# Step 3: Apply Gaussian filters with multiple sigma values
sigmas = [1, 2, 3, 4, 5]
denoised_imgs = [nd.gaussian_filter(gray, sigma=s) for s in sigmas]

# Step 4: Display comparison
plt.figure(figsize=(16, 8))
plt.subplot(1, len(sigmas) + 1, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original (Noisy)")
plt.axis('off')

for i, (s, img_f) in enumerate(zip(sigmas, denoised_imgs), start=2):
    plt.subplot(1, len(sigmas) + 1, i)
    plt.imshow(img_f, cmap='gray')
    plt.title(f"Gaussian σ={s}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ...
# 📤 Upload your noisy image:
#      <input type="file" id="files-c1181af4-24ef-4606-8f23-cc9821b35d0f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c1181af4-24ef-4606-8f23-cc9821b35d0f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# !pip install scikit-image scipy matplotlib

from skimage import io, color, img_as_float, img_as_ubyte
from scipy import ndimage as nd
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files

# Upload image
print("📤 Upload your noisy image:")
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# Read image
img = io.imread(img_path)

# If image has 4 channels (RGBA), convert to RGB
if img.ndim == 3 and img.shape[-1] == 4:
    img = img[..., :3]

# Convert to grayscale and normalize
gray = color.rgb2gray(img)
gray = img_as_float(gray)

# Step 3: Apply Gaussian filters with multiple sigma values
sigmas = [1, 2, 3, 4, 5]
denoised_imgs = [nd.gaussian_filter(gray, sigma=s) for s in sigmas]

# Step 4: Display comparison
plt.figure(figsize=(16, 8))
plt.subplot(1, len(sigmas) + 1, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original (Noisy)")
plt.axis('off')

for i, (s, img_f) in enumerate(zip(sigmas, denoised_imgs), start=2):
    plt.subplot(1, len(sigmas) + 1, i)
    plt.imshow(img_f, cmap='gray')
    plt.title(f"Gaussian σ={s}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ...
# 📤 Upload your noisy image:
#      <input type="file" id="files-fecd2123-70cb-42a9-8db6-a95750999ec9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fecd2123-70cb-42a9-8db6-a95750999ec9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
from skimage import io, color, img_as_float, img_as_ubyte
from scipy.ndimage import gaussian_filter
import matplotlib.pyplot as plt
from google.colab import files

# -------------------------------
# Step 1: Upload Image
# -------------------------------
print("📤 Upload your noisy image:")
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# -------------------------------
# Step 2: Read and preprocess
# -------------------------------
img = io.imread(img_path)

# Convert RGBA to RGB if needed
if img.ndim == 3 and img.shape[-1] == 4:
    img = img[..., :3]

# Convert to grayscale and normalize
gray = img_as_float(color.rgb2gray(img))

# -------------------------------
# Step 3: Apply Gaussian denoising
# -------------------------------
sigmas = [1, 2, 3, 4, 5]
denoised_imgs = [gaussian_filter(gray, sigma=s) for s in sigmas]

# -------------------------------
# Step 4: Display results
# -------------------------------
plt.figure(figsize=(18, 6))
plt.subplot(1, len(sigmas) + 1, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original")
plt.axis('off')

for i, (s, img_f) in enumerate(zip(sigmas, denoised_imgs), start=2):
    plt.subplot(1, len(sigmas) + 1, i)
    plt.imshow(img_f, cmap='gray')
    plt.title(f"σ={s}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 📤 Upload your noisy image:
#      <input type="file" id="files-5cccd33b-2d04-4ee6-a5d5-2f5bc3b26e76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5cccd33b-2d04-4ee6-a5d5-2f5bc3b26e76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
