# %% [markdown]
# **Denoising Image (Only Median Filter)**
#
#
# Acknowledgments for images:
# 1) https://assets-global.website-files.com/5fa655b56251b0e528b5207a/5fd602c54370aa656077919e_Scanning%20Electron%20Microscope.pdf
#
# 2) https://www.btraindia.com/wp-content/uploads/2022/07/SEM.pdf

# %%
from skimage import io, color, img_as_float, img_as_ubyte
from scipy.ndimage import median_filter
import matplotlib.pyplot as plt
from google.colab import files

# -------------------------------
# Step 1: Upload noisy image
# -------------------------------
print("Upload your noisy image:")
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# -------------------------------
# Step 2: Read and preprocess
# -------------------------------
img = io.imread(img_path)

# Convert RGBA → RGB if needed
if img.ndim == 3 and img.shape[-1] == 4:
    img = img[..., :3]

# Convert to grayscale and normalize
gray = img_as_float(color.rgb2gray(img))

# -------------------------------
# Step 3: Apply Median Filtering
# -------------------------------
# Try different kernel sizes: 3, 5, 7 for comparison
kernel_sizes = [3, 5, 7]
median_imgs = [median_filter(gray, size=k) for k in kernel_sizes]

# -------------------------------
# Step 4: Display results
# -------------------------------
plt.figure(figsize=(16, 6))
plt.subplot(1, len(kernel_sizes) + 1, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original")
plt.axis('off')
plt.imshow(img)

for i, (k, img_f) in enumerate(zip(kernel_sizes, median_imgs), start=2):
    plt.subplot(1, len(kernel_sizes) + 1, i)
    plt.imshow(img_f, cmap='gray')
    plt.title(f"Median size={k}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Upload your noisy image:
#      <input type="file" id="files-9e4496cf-a8e5-483f-902f-1f5b8b59d50a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e4496cf-a8e5-483f-902f-1f5b8b59d50a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
from skimage import io, color, img_as_float, img_as_ubyte
from scipy.ndimage import median_filter
import matplotlib.pyplot as plt
from google.colab import files

# -------------------------------
# Step 1: Upload noisy image
# -------------------------------
print(" Upload your noisy image:")
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# -------------------------------
# Step 2: Read and preprocess
# -------------------------------
img = io.imread(img_path)

# Convert RGBA → RGB if needed
if img.ndim == 3 and img.shape[-1] == 4:
    img = img[..., :3]

# Convert to grayscale and normalize
gray = img_as_float(color.rgb2gray(img))

# -------------------------------
# Step 3: Apply Median Filtering
# -------------------------------
# Try different kernel sizes: 3, 5, 7 for comparison
kernel_sizes = [3, 5, 7]
median_imgs = [median_filter(gray, size=k) for k in kernel_sizes]

# -------------------------------
# Step 4: Display results
# -------------------------------
plt.figure(figsize=(16, 6))
plt.subplot(1, len(kernel_sizes) + 1, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original")
plt.axis('off')
plt.imshow(img)

for i, (k, img_f) in enumerate(zip(kernel_sizes, median_imgs), start=2):
    plt.subplot(1, len(kernel_sizes) + 1, i)
    plt.imshow(img_f, cmap='gray')
    plt.title(f"Median size={k}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
#  Upload your noisy image:
#      <input type="file" id="files-01f5cfb3-bb1b-4ead-9440-d5e522e752fb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-01f5cfb3-bb1b-4ead-9440-d5e522e752fb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
from skimage import io, color, img_as_float, img_as_ubyte
from scipy.ndimage import median_filter
import matplotlib.pyplot as plt
from google.colab import files

# -------------------------------
# Step 1: Upload noisy image
# -------------------------------
print("Upload your noisy image:")
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# -------------------------------
# Step 2: Read and preprocess
# -------------------------------
img = io.imread(img_path)

# Convert RGBA → RGB if needed
if img.ndim == 3 and img.shape[-1] == 4:
    img = img[..., :3]

# Convert to grayscale and normalize
gray = img_as_float(color.rgb2gray(img))

# -------------------------------
# Step 3: Apply Median Filtering
# -------------------------------
# Try different kernel sizes: 3, 5, 7 for comparison
kernel_sizes = [3, 5, 7]
median_imgs = [median_filter(gray, size=k) for k in kernel_sizes]

# -------------------------------
# Step 4: Display results
# -------------------------------
plt.figure(figsize=(16, 6))
plt.subplot(1, len(kernel_sizes) + 1, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original")
plt.axis('off')
plt.imshow(img)
for i, (k, img_f) in enumerate(zip(kernel_sizes, median_imgs), start=2):
    plt.subplot(1, len(kernel_sizes) + 1, i)
    plt.imshow(img_f, cmap='gray')
    plt.title(f"Median size={k}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Upload your noisy image:
#      <input type="file" id="files-2dc1aba6-46e1-47cd-be36-f7d11c43c1a5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2dc1aba6-46e1-47cd-be36-f7d11c43c1a5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
from skimage import io, color, img_as_float, img_as_ubyte
from scipy.ndimage import median_filter
import matplotlib.pyplot as plt
from google.colab import files

# -------------------------------
# Step 1: Upload noisy image
# -------------------------------
print("Upload your noisy image:")
uploaded = files.upload()
img_path = list(uploaded.keys())[0]

# -------------------------------
# Step 2: Read and preprocess
# -------------------------------
img = io.imread(img_path)

# Convert RGBA → RGB if needed
if img.ndim == 3 and img.shape[-1] == 4:
    img = img[..., :3]

# Convert to grayscale and normalize
gray = img_as_float(color.rgb2gray(img))

# -------------------------------
# Step 3: Apply Median Filtering
# -------------------------------
# Try different kernel sizes: 3, 5, 7 for comparison
kernel_sizes = [3, 5, 7]
median_imgs = [median_filter(gray, size=k) for k in kernel_sizes]

# -------------------------------
# Step 4: Display results
# -------------------------------
plt.figure(figsize=(16, 6))
plt.subplot(1, len(kernel_sizes) + 1, 1)
plt.imshow(gray, cmap='gray')
plt.title("Original")
plt.axis('off')
plt.imshow(img)
for i, (k, img_f) in enumerate(zip(kernel_sizes, median_imgs), start=2):
    plt.subplot(1, len(kernel_sizes) + 1, i)
    plt.imshow(img_f, cmap='gray')
    plt.title(f"Median size={k}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Upload your noisy image:
#      <input type="file" id="files-d722a9dc-d9d9-4d53-80d9-6ff1ebfcb414" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d722a9dc-d9d9-4d53-80d9-6ff1ebfcb414">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...
